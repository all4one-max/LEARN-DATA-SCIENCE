# %% [markdown]
# ### ADDING NEW FEATURES TO BOSTON DATASET AND COMPARING NEW AND OLD TEST SCORE

# %%
from sklearn import datasets
import pandas as pd,numpy as np

# %%
boston=datasets.load_boston()
X=boston.data
Y=boston.target

# %%
df=pd.DataFrame(X,columns=boston.feature_names)
curr=1
for ele in df.columns:
    df[ele+'_'+str(curr)]=df[ele]**2
    curr+=1
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  ...  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0  ...
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0  ...
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0  ...
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0  ...
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0  ...
#
#    CHAS_4     NOX_5       RM_6    AGE_7      DIS_8  RAD_9   TAX_10  \
# 0     0.0  0.289444  43.230625  4251.04  16.728100    1.0  87616.0
# 1     0.0  0.219961  41.229241  6225.21  24.672082    4.0  58564.0
# 2     0.0  0.219961  51.624225  3733.21  24.672082    4.0  58564.0
# 3     0.0  0.209764  48.972004  2097.64  36.750269    9.0  49284.0
# 4     0.0  0.209764  51.079609  2937.64  36.750269    9.0  49284.0
#
#    PTRATIO_11         B_12  LSTAT_13
# 0      234.09  157529.6100   24.8004
# 1      316.84  157529.6100   83.5396
# 2      316.84  154315.4089   16.2409
# 3      349.69  155732.8369    8.6436
# 4      349.69  157529.6100   28.4089
#
# [5 rows x 26 columns]

# %%
print(X.shape)
X2=df.values
print(X2.shape)
# Out:
# (506, 13)
# (506, 26)

# %%
from sklearn import model_selection
X_train,X_test,Y_train,Y_test=model_selection.train_test_split(X,Y,random_state=0)
X2_train,X2_test,Y2_train,Y2_test=model_selection.train_test_split(X2,Y,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
algo1=LinearRegression()
algo2=LinearRegression()

# %%
algo1.fit(X_train,Y_train)
algo2.fit(X2_train,Y2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(algo1.score(X_train,Y_train))
print(algo1.score(X_test,Y_test))
print(algo2.score(X2_train,Y2_train))
print(algo2.score(X2_test,Y_test))
# Out:
# 0.7697699488741149
# 0.6354638433202129
# 0.8596413794910498
# 0.7200918269122947

# %% [markdown]
# ### GRADIENT DESCENT

# %%
def step_gradient(points,learning_rate,m,c):
    N=len(points)
    slope_m,slope_c=0,0
    for i in range(N):
        x,y=points[i,0],points[i,1]
        slope_m+=(-2/N)*(y-m*x-c)*(x)
        slope_c+=(-2/N)*(y-m*x-c)
    new_m=m-learning_rate*slope_m
    new_c=c-learning_rate*slope_c
    return new_m,new_c

def gd(points,learning_rate,no_iterations):
    m,c=0,0
    for i in range(no_iterations):
        m,c=step_gradient(points,learning_rate,m,c)
        cst=cost(points,m,c)
        print(m,c,cst)
    return m,c

def cost(points,m,c):
    N=len(points)
    cst=0
    for i in range(N):
        x,y=points[i,0],points[i,1]
        cst+=(1/N)*((y-m*x-c)**2)
    return cst

def run():
    data=np.loadtxt("C:\\Users\\jhasa\\Desktop\\data.csv",delimiter=',')
    learning_rate=0.0001
    no_iterations=100
    m,c=gd(data,learning_rate,no_iterations)
    print(m,c)
run()
# Out:
# 0.7370702973591053 0.014547010110737297 1484.5865574086486
# 1.1067954543515157 0.02187396295959641 457.8542575737672
# 1.2922546649131115 0.025579224321293136 199.5099857255389
# 1.385283255651245 0.027467789559144355 134.50591058200533
# 1.4319472323843205 0.028445071981738963 118.1496934223995
# 1.4553540088980408 0.028965240766478616 114.0341490603815
# 1.4670946177201354 0.029256114126046697 112.99857731713657
# 1.4729832982243762 0.029431969163807123 112.73798187568467
# 1.4759365618962286 0.029550129024383066 112.6723843590911
# 1.47741737554838 0.029639347874732384 112.65585181499745
# 1.4781595857319894 0.029714049245227036 112.65166489759581
# 1.4785313011122556 0.029781468199526512 112.6505843615011
# 1.4787171706313593 0.02984523395633241 112.65028544701502
# 1.47880981702566 0.029907166987310232 112.65018320293967
# 1.4788557012777628 0.029968180468920386 112.650130445072
# 1.4788781289278565 0.030028732464457787 112.65009013922885
# 1.4788887903917065 0.03008905274548579 112.6500529669463
# 1.4788935497608395 0.030149256568940054 112.65001658353178
# 1.4788953485533445 0.0302094017494658 112.64998039901865
# 1.478895662279729 0.030269517287775903 112.64994426496071
# 1.4788952310786534 0.030329617731073653 112.64990814400622
# 1.4788944262150017 0.03038971037646064 112.64987202675677
# 1.4788934339209232 0.03044979888427645 112.64983591084761
# 1.4788923476133156 0.030509885090605163 112.64979979568368
# 1.4788912141515247 0.030569969916456365 112.64976368111523
# 1.4788900570409158 0.030630053823824277 112.64972756710469
# 1.4788888880721398 0.030690137044453975 112.64969145364236
# 1.478887713159568 0.030750219694594044 112.64965534072611
# 1.4788865352699392 0.030810301832558264 112.64961922835512
# 1.4788853558914152 0.03087038348759942 112.64958311652944
# 1.4788841757704807 0.030930464674392866 112.64954700524868
# 1.4788829952815838 0.03099054540030169 112.64951089451318
# 1.4788818146125533 0.03105062566902103 112.64947478432279
# 1.478880633857607 0.031110705482406138 112.64943867467744
# 1.4788794530640061 0.031170784841389337 112.64940256557728
# 1.4788782722554572 0.03123086374644 112.64936645702221
# 1.478877091443852 0.03129094219779528 112.64933034901203
# 1.4788759106351557 0.03135102019557585 112.64929424154704
# 1.4788747298323603 0.03141109773984393 112.64925813462712
# 1.4788735490369667 0.03147117483063244 112.6492220282522
# 1.4788723682497276 0.03153125146795962 112.64918592242235
# 1.4788711874710208 0.031591327651836296 112.64914981713754
# 1.4788700067010354 0.03165140338226962 112.64911371239779
# 1.4788688259398666 0.03171147865926489 112.64907760820296
# 1.478867645187562 0.03177155348282645 112.64904150455324
# 1.4788664644441452 0.031831627852958205 112.64900540144845
# 1.4788652837096283 0.031891701769663806 112.64896929888867
# 1.4788641029840173 0.031951775232946796 112.64893319687388
# 1.478862922267315 0.032011848242810656 112.6488970954041
# 1.478861741559523 0.03207192079925884 112.64886099447922
# 1.478860560860642 0.032131992902294786 112.64882489409929
# 1.478859380170672 0.03219206455192192 112.64878879426433
# 1.4788581994896135 0.032252135748143666 112.64875269497436
# 1.4788570188174663 0.03231220649096346 112.64871659622933
# 1.4788558381542305 0.032372276780384714 112.64868049802914
# 1.478854657499906 0.032432346616410854 112.648644400374
# 1.4788534768544928 0.0324924159990453 112.64860830326366
# 1.4788522962179906 0.03255248492829148 112.64857220669828
# 1.4788511155903998 0.03261255340415281 112.64853611067772
# 1.47884993497172 0.032672621426632714 112.64850001520212
# 1.478848754361951 0.032732688995734616 112.64846392027131
# 1.4788475737610933 0.032792756111461936 112.64842782588545
# 1.4788463931691462 0.0328528227738181 112.64839173204442
# 1.47884521258611 0.03291288898280652 112.6483556387483
# 1.4788440320119847 0.03297295473843063 112.64831954599697
# 1.47884285144677 0.03303302004069384 112.64828345379043
# 1.4788416708904657 0.03309308488959958 112.64824736212877
# 1.478840490343072 0.03315314928515128 112.64821127101193
# 1.4788393098045889 0.033213213227352344 112.64817518043986
# 1.4788381292750161 0.0332732767162062 112.64813909041264
# 1.4788369487543536 0.033333339751716276 112.64810300093015
# 1.4788357682426014 0.033393402333885984 112.64806691199259
# 1.4788345877397595 0.033453464462718754 112.64803082359971
# 1.4788334072458276 0.033513526138218 112.64799473575155
# 1.4788322267608058 0.03357358736038715 112.64795864844827
# 1.478831046284694 0.03363364812922963 112.64792256168963
# 1.4788298658174923 0.033693708444748845 112.64788647547579
# 1.4788286853592003 0.03375376830694823 112.64785038980668
# 1.478827504909818 0.0338138277158312 112.64781430468226
# 1.4788263244693456 0.03387388667140118 112.64777822010265
# 1.4788251440377829 0.03393394517366159 112.6477421360677
# 1.4788239636151297 0.03399400322261586 112.64770605257743
# 1.478822783201386 0.034054060818267395 112.64766996963193
# 1.4788216027965517 0.03411411796061963 112.64763388723107
# 1.478820422400627 0.03417417464967598 112.64759780537483
# 1.4788192420136115 0.03423423088543987 112.64756172406335
# 1.478818061635505 0.034294286667914724 112.6475256432965
# 1.478816881266308 0.03435434199710396 112.64748956307432
# 1.47881570090602 0.03441439687301099 112.64745348339677
# 1.4788145205546412 0.034474451295639245 112.64741740426388
# 1.4788133402121713 0.034534505264992146 112.6473813256756
# 1.4788121598786104 0.03459455878107311 112.64734524763193
# 1.4788109795539583 0.03465461184388557 112.64730917013293
# 1.478809799238215 0.03471466445343293 112.6472730931785
# 1.4788086189313803 0.03477471660971862 112.64723701676861
# 1.4788074386334544 0.03483476831274606 112.64720094090339
# 1.478806258344437 0.03489481956251867 112.64716486558265
# 1.4788050780643283 0.03495487035903988 112.64712879080662
# 1.4788038977931277 0.0350149207023131 112.64709271657513
# 1.4788027175308358 0.035074970592341756 112.64705664288809
# 1.4788027175308358 0.035074970592341756
