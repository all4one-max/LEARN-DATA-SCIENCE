# %% [markdown]
# ### LET'S START WITH SELENIUM

# %%
from selenium import webdriver

driver = webdriver.Chrome(r"C:\\Users\\jhasa\\Desktop\\chromedriver")
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="a70fd8e4749ad522ef9a8d4914e49608")>

# %%
driver.get("https://codingninjas.com/")

# %%
driver.maximize_window()

# %%
driver.refresh()

# %%
driver.title
# Out:
# "Practice & Learn Coding Online at India's Best Coding Courses - Coding Ninjas"

# %%
driver.back()

# %%
driver.forward()

# %%
driver.save_screenshot('test_shot.png')
# Out:
# True

# %%
driver.page_source
# Out:
# '<html lang="en" style="--batchMonthBG:#FFEBC2; --batchCardBC:#FFEBC2; --batchMonthTC:#AC933C;"><head>\n    <meta charset="utf-8">\n    <title>Practice &amp; Learn Coding Online at India\'s Best Coding Courses - Coding Ninjas</title>\n\n    <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n    <meta name="title" content="Coding Ninjas">\n    <meta property="og:title" content="Practice &amp; Learn Coding Online at India\'s Best Coding Courses - Coding Ninjas">\n    <meta name="description" content="Practice Coding Online at Coding Ninjas which is India\'s best Programming and software training institute that offers courses in Java, C++, Android, Data Structure, Web Development, Ruby on Rails and more. Registration open for Online Coding Classes and offline Coding Classes in Delhi.">\n    <meta property="og:description" content="Practice Coding Online at Coding Ninjas which is India\'s best Programming and software training institute that off
# ...

# %%
eve_btn=driver.find_element_by_link_text("Events")
eve_btn.click()

# %%
driver.back()

# %%
crs_btn=driver.find_element_by_partial_link_text("Eve")
crs_btn.click()

# %%
driver.quit()

# %% [markdown]
# ### GOOGLE

# %%
from selenium import webdriver

driver = webdriver.Chrome(r"C:\\Users\\jhasa\\Desktop\\chromedriver")
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="87897eb3f45de77db83d2683835fb0f3")>

# %%
driver.get("https://www.google.com/")

# %%
btn=driver.find_element_by_partial_link_text("mage")
btn.click()

# %%
driver.title
# Out:
# 'Google Images'

# %%
driver.back()

# %%
driver.close()

# %% [markdown]
# ### FACEBOOK

# %%
from selenium import webdriver

driver = webdriver.Chrome(r"C:\\Users\\jhasa\\Desktop\\chromedriver")

# %%
driver.get("https://www.facebook.com/")

# %%
c=driver.find_element_by_name("firstname")

# %%
c.is_enabled()
# Out:
# True

# %%
c=driver.find_element_by_id('day')

# %%
c.click()

# %%
driver.forward()

# %%
c=driver.find_element_by_id("u_0_6")

# %%
c.click()

# %%
c.is_selected()
# Out:
# True

# %%
driver.quit()

# %% [markdown]
# ### LOCATE ELEMENT USING XPATH()

# %%
from selenium import webdriver

driver = webdriver.Chrome(r"C:\\Users\\jhasa\\Desktop\\chromedriver")

# %%
driver.get("http://books.toscrape.com/")

# %%
c=driver.find_element_by_xpath('/html/head/title')

# %%
c.get_attribute('outerHTML')
# Out:
# '<title>\n    All products | Books to Scrape - Sandbox\n</title>'

# %%
c.get_attribute('innerHTML')
# Out:
# '\n    All products | Books to Scrape - Sandbox\n'

# %%
c=driver.find_element_by_xpath('/html/body/div/div/ul')

# %%
c.get_attribute('outerHTML')
# Out:
# '<ul class="breadcrumb">\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    </ul>'

# %%
c=driver.find_element_by_xpath('//ul[@class="breadcrumb"]')
c
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2906ba141d8b8a9aa33128673b8315ad", element="6efbd101-388c-4938-a9c1-23a2b163430f")>

# %%
c.get_attribute('outerHTML')
# Out:
# '<ul class="breadcrumb">\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    </ul>'

# %%
c=driver.find_element_by_xpath('//*')

# %%
c.get_attribute('outerHTML')
# Out:
# '<html lang="en-us" class="no-js"><!--<![endif]--><head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n        <meta name="created" content="24th Jun 2016 09:29">\n        <meta name="description" content="">\n        <meta name="viewport" content="width=device-width">\n        <meta name="robots" content="NOARCHIVE,NOCACHE">\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" href="static/oscar/favicon.ico">\n        \n\n        \n        \n    \n    \n        <link rel="stylesheet" type="text/css" href="static/oscar/css/styles.css">\n    \n    <link rel="stylesheet" href="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css">\n    <link rel="stylesheet" type="text/cs
# ...

# %%
c=driver.find_element_by_xpath('//div[@class="col-sm-8 h1"]')

# %%
c.get_attribute('outerHTML')
# Out:
# '<div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n</div>'

# %%
c=driver.find_element_by_xpath('//div[contains(@class,"h1")]')

# %%
c.get_attribute('outerHTML')
# Out:
# '<div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n</div>'

# %%
c=driver.find_element_by_xpath('//ul[contains(@class,"nav")]//ul/li[4]')

# %%
c.get_attribute('outerHTML')
# Out:
# '<li>\n                        <a href="catalogue/category/books/sequential-art_5/index.html">\n                            \n                                Sequential Art\n                            \n                        </a>\n\n                        </li>'

# %%
c=driver.find_element_by_xpath('//ul[contains(@class,"nav")]//ul/li[last()]')

# %%
c.get_attribute('outerHTML')
# Out:
# '<li>\n                        <a href="catalogue/category/books/crime_51/index.html">\n                            \n                                Crime\n                            \n                        </a>\n\n                        </li>'

# %%
driver.quit()

# %% [markdown]
# ### LOCATE ELEMENT USING CSS SELECTOR

# %%
from selenium import webdriver
driver = webdriver.Chrome(r"C:\\Users\\jhasa\\Desktop\\chromedriver")
driver.get("http://books.toscrape.com/")

# %%
c=driver.find_element_by_css_selector("html head title")
c.get_attribute('innerHTML')
# Out:
# '\n    All products | Books to Scrape - Sandbox\n'

# %%
c=driver.find_element_by_css_selector("div.page_inner ul li")
c.get_attribute('innerHTML')
# Out:
# '\n            <a href="index.html">Home</a>\n        '

# %%
driver.quit()

# %% [markdown]
# ### NGA

# %%
from selenium import webdriver
driver = webdriver.Chrome(r"C:\\Users\\jhasa\\Desktop\\chromedriver")
driver.get("https://www.nga.gov/collection/artists.html")

# %%
c=driver.find_element_by_css_selector("div.page_inner>ul>li")
c.get_attribute('innerHTML')
# Out:
# '\n            <a href="index.html">Home</a>\n        '

# %%
c=driver.find_elements_by_css_selector("li.art>div>dl>dt>a")
for ele in c:
    print(ele)
Abbati, Pietro Giovanni
Abbatini, Guido Ubaldole.text
# Out:
# 107 Workshop
# 2 Bit Comics
# 2RC Gallery
# 7 Freds Press
# A. B.
# A. Brett & Company
# A. Lublin
# Aachen, Hans von
# Aarland, Johann Carl Wilhelm
# Abakanowicz, Magdalena
# Abate, Niccolò dell'
# Abbati, Pietro Giovanni
# Abbatini, Guido Ubaldo
# Abbe, Elfriede Martha
# Abbé, Salomon van
# Abbe, William Parker
# Abbey, Edwin Austin
# Abbiati, Giuseppe
# Abbot, John
# Abbott, Berenice

# %%
driver.quit()

# %% [markdown]
# ### TYPE INTO FIELDS

# %%
from selenium import webdriver
driver = webdriver.Chrome(r"C:\\Users\\jhasa\\Desktop\\chromedriver")
driver.get("https://www.google.co.in/")

# %%
c=driver.find_element_by_name('q')

# %%
c.send_keys('COVID-19')

# %%
c.submit()

# %%
driver.get('https://www.google.co.in/maps?hl=en&tab=wl&authuser=0')

# %%
c=driver.find_element_by_name('q')

# %%
c.send_keys('Brahma Apartments')

# %%
driver.find_element_by_class_name("searchbox-searchbutton").click()

# %%
driver.quit()

# %% [markdown]
# ### LOG IN TO FACEBOOK

# %%
from selenium import webdriver
driver = webdriver.Chrome(r"C:\\Users\\jhasa\\Desktop\\chromedriver")
driver.get("https://www.facebook.com/")

# %%
e=driver.find_element_by_name("email")
p=driver.find_element_by_name("pass")

# %%
e.send_keys("####################")
p.send_keys("###########################")

# %%
driver.find_element_by_id("u_0_b").click()

# %%
driver.quit()

# %% [markdown]
# ### TOPOLOGICAL SORTING - GFG

# %%
from selenium import webdriver
driver = webdriver.Chrome(r"C:\\Users\\jhasa\\Desktop\\chromedriver")
driver.get("https://www.geeksforgeeks.org/")

# %%
c=driver.find_element_by_partial_link_text("Tutorials")

# %%
c.click()

# %%
d=driver.find_element_by_partial_link_text("Data Structures")

# %%
d.click()

# %%
e=driver.find_element_by_partial_link_text("Graph")

# %%
e.click()

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
res=requests.get(driver.current_url)
data=bs(res.text,'html.parser')

# %%
fnd=data.find(class_="topologicalSorting").contents

# %%
dat=fnd[1].contents

# %%
for i in range(1,len(dat),2):
    print(dat[i].string)
# Out:
# Topological Sorting
# All topological sorts of a Directed Acyclic Graph
# Kahn’s Algorithm for Topological Sorting
# Maximum edges that can be added to DAG so that is remains DAG
# Longest path between any pair of vertices
# Longest Path in a Directed Acyclic Graph
# Longest Path in a Directed Acyclic Graph | Set 2
# Topological Sort of a graph using departure time of vertex
# Given a sorted dictionary of an alien language, find order of characters

# %%
driver.quit()
